# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

data = pd.read_csv('student_data.csv')
X = data[['studytime']] #double brackets for 2D input
y = data[['failures']]  # target column


model = LinearRegression()
model.fit(X, y)

predicted_score = model.predict(X)

#evaluate

mae = mean_absolute_error(y, predicted_score)
mse = mean_squared_error(y, predicted_score)
rmse = np.sqrt(mse)

#show results

print('Mean absolute error : ',mae)
print('Mean Squared erroe : ',mse)
print('root mean absolute error : ',rmse)
# Out:
# Mean absolute error :  0.5116079369885533
# Mean Squared erroe :  0.5349997563371399
# root mean absolute error :  0.7314367753518686

# %%
''' 3 step formula

1 - X and y numeric ?
plot a scatter plot
to know relationships


2 - Is one column a category
then
bar plot / count plot


3 - want to see a distribution ?
shape ? --> Histogram / KDE plot/ Box plot  '''
# Out:
# ' 3 step formula\n\n1 - X and y numeric ?\nplot a scatter plot\nto know relationships\n\n\n2 - Is one column a category\nthen\nbar plot / count plot\n\n\n3 - want to see a distribution ?\nshape ? --> Histogram / KDE plot/ Box plot  '

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib as plt
import numpy as np
import matplotlib.pyplot as plt

#load dataset

data = pd.read_csv('student_data.csv')

x = data[['studytime']]
y = data['failures']

model = LinearRegression()
model.fit(X, y)
predicted_scores = model.predict(X)

# valid  regression matrix
mae = mean_absolute_error(y, predicted_scores)
mse = mean_squared_error(y, predicted_scores)
rmse = np.sqrt(mse)
r2 = r2_score(y, predicted_scores)

print('Mean absolute error : ', round(mae, 2))
print('Mean Squared erroe : ',mse)
print('root mean absolute error : ',rmse)
print('r2 score : ', r2)


# histogram

plt.figure(figsize=(10, 6))
plt.hist(data['failures'], bins = 30, color = 'skyblue', edgecolor = 'black')
plt.title('Distribution of number of failures')
plt.xlabel('number of times failed')
plt.ylabel('number of students')
plt.grid(True)
plt.show()
# Out:
# Mean absolute error :  0.51
# Mean Squared erroe :  0.5349997563371399
# root mean absolute error :  0.7314367753518686
# r2 score :  0.030124125874302687

# %%
plt.figure(figsize=(10, 6))
plt.scatter(X, y, color = 'skyblue', label = 'failure rate')
plt.plot(X, predicted_scores, color = 'red', label = 'predicted scores (Regression line )')
plt.title('model pred vs actual failiure rate')
plt.xlabel('number of times failed')
plt.ylabel('final output')
plt.grid(True)
plt.show()

new_hours = 9
pred_new_score = model.predict([[new_hours]])
print('Predicted final P/F for {new_hours}  hours is {pred_new_score}')
# Out:
# Predicted final P/F for {new_hours}  hours is {pred_new_score}
# C:\Users\jasas\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
